# %% [raw]
# ---
# execute:
#   enabled: false
# format:
#   html:
#     code-fold: false
# jupyter: python3
# ---

# %% [markdown]
# # How to create an NDVI Time series using openEO
#
# This notebook presents an application case, that demonstrates how to display the NDVI (Normalized Difference Vegetation Index) timeseries for specific fields. The case study showcases the process of selecting the fields and generating average NDVI timeseries data for analysis and visualization.

# %% [markdown]
# ## Setup

# %%
import json

import pandas as pd
import matplotlib.pyplot as plt
import scipy.signal
import numpy as np

import openeo

# %% [markdown]
# Establish an authenticated connection to Copernicus Data Space Ecosystem openEO back-end.

# %%
connection = openeo.connect(url="openeo.dataspace.copernicus.eu")
connection.authenticate_oidc()
# Out:
# Authenticated using refresh token.
# <Connection to 'https://openeo.dataspace.copernicus.eu/openeo/1.1/' with OidcBearerAuth>

# %% [markdown]
# ## Basic NDVI Timeseries

# %% [markdown]
# We want to calculate the NDVI values in a couple of fields in a time window of a couple of months.
#
# For simplicty, we load the field geometries as an inline GeoJSON feature collection:

# %%
# Polygon for Darmstadt
fields = json.loads(
    """{
    "type": "FeatureCollection",
    "features": [
        {"type": "Feature", "properties": {}, "geometry": {"type": "Polygon", "coordinates": [ [ [ 8.4773254, 49.9627057 ], [ 8.4793854, 49.8202651 ], [ 8.8913727, 49.8091884 ], [ 8.8879395, 49.9693309 ], [ 8.4773254, 49.9627057]]]}}
    ]}
"""
)

# %% [markdown]
# Load the "B04" (red) and "B08" (NIR) brands from the  `SENTINEL2_L2A` collection for the desired time window:

# %% [markdown]
# ### polygon
# 8.4773254, 49.9627057
# 8.4793854, 49.8202651
# 8.8913727, 49.8091884
# 8.8879395, 49.9693309
# 8.4773254, 49.9627057
#
# ###bigger polygon
# 8.4718323, 49.9746304
# 8.4498596, 49.8060865
#
# 8.9236450, 49.7954499
# 8.9188385, 49.9781631
#
# 8.4718323, 49.9746304
#
#
#         "west": 8.4498596,
#         "south": 49.7954499,
#         "east": 8.9236450,
#         "north": 49.9746304,

# %%
# Bigger surrounding darmstadt coordinates
s2cube = connection.load_collection(
    "SENTINEL2_L2A",
    temporal_extent=["2023-01-01", "2023-10-01"],
    spatial_extent={
        "west": 8.4498596,
        "south": 49.7954499,
        "east": 8.9236450, 
        "north": 49.9746304,
        "crs": "EPSG:4326",
    },
 
    bands=["B04", "B08"],
)

# %% [markdown]
# Note here that it is not necessary to specify a spatial extent in `load_collection`,
# because we will provide the field geometries in a later step.
# The openEO back-end will automatically limit the effective data loading to the necessary bounding box.
#
# Calculate the NDVI from the red and NIR bands:

# %%
red = s2cube.band("B04")
nir = s2cube.band("B08")
ndvi = (nir - red) / (nir + red)

# %% [markdown]
# With the `DataCube.aggregate_spatial()` method , we can calculate the mean NDVI for each of the fields.

# %%
timeseries = ndvi.aggregate_spatial(geometries=fields, reducer="mean")

# %% [markdown]
# We now execute this as a batch job and download the timeseries in CSV format.

# %%
job = timeseries.execute_batch(out_format="CSV", title="NDVI timeseries")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/.conda/envs/ml_env/lib/python3.11/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/.conda/envs/ml_env/lib/python3.11/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~/.conda/envs/ml_env/lib/python3.11/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1374 try:
# -> 1375     response.begin()
#    1376 except ConnectionError:
#
# File ~/.conda/envs/ml_env/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~/.conda/envs/ml_env/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File ~/.conda/envs/ml_env/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     705 try:
# --> 706     return self._sock.recv_into(b)
#     707 except timeout:
#
# File ~/.conda/envs/ml_env/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#
# File ~/.conda/envs/ml_env/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1133 if buffer is not None:
# -> 1134     return self._sslobj.read(len, buffer)
#    1135 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/.conda/envs/ml_env/lib/python3.11/site-packages/requests/adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#
# File ~/.conda/envs/ml_env/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File ~/.conda/envs/ml_env/lib/python3.11/site-packages/urllib3/util/retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~/.conda/envs/ml_env/lib/python3.11/site-packages/urllib3/packages/six.py:770, in reraise(tp, value, tb)
#     769         raise value.with_traceback(tb)
# --> 770     raise value
#     771 finally:
#
# File ~/.conda/envs/ml_env/lib/python3.11/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/.conda/envs/ml_env/lib/python3.11/site-packages/urllib3/connectionpool.py:451, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     452     raise
#
# File ~/.conda/envs/ml_env/lib/python3.11/site-packages/urllib3/connectionpool.py:340, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     339 if isinstance(err, SocketTimeout):
# --> 340     raise ReadTimeoutError(
#     341         self, url, "Read timed out. (read timeout=%s)" % timeout_value
#     342     )
#     344 # See the above comment about EAGAIN in Python 3. In Python 2 we have
#     345 # to specifically catch it and throw the timeout error
#
# ReadTimeoutError: HTTPSConnectionPool(host='openeo.dataspace.copernicus.eu', port=443): Read timed out. (read timeout=1200)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 job = timeseries.execute_batch(out_format="CSV", title="NDVI timeseries")
#
# File ~/.conda/envs/ml_env/lib/python3.11/site-packages/openeo/rest/vectorcube.py:290, in VectorCube.execute_batch(self, outputfile, out_format, print, max_poll_interval, connection_retry_interval, job_options, **format_options)
#     286 if out_format is None and outputfile:
#     287     # TODO #401/#449 don't guess/override format if there is already a save_result with format?
#     288     out_format = guess_format(outputfile)
# --> 290 job = self.create_job(out_format, job_options=job_options, **format_options)
#     291 return job.run_synchronous(
#     292     # TODO #135 support multi file result sets too
#     293     outputfile=outputfile,
#     294     print=print, max_poll_interval=max_poll_interval, connection_retry_interval=connection_retry_interval
#     295 )
#
# File ~/.conda/envs/ml_env/lib/python3.11/site-packages/openeo/rest/vectorcube.py:323, in VectorCube.create_job(self, out_format, title, description, plan, budget, job_options, **format_options)
#     320 # TODO: avoid using all kwargs as format_options
#     321 # TODO: centralize `create_job` for `DataCube`, `VectorCube`, `MlModel`, ...
#     322 cube = self._ensure_save_result(format=out_format, options=format_options or None)
# --> 323 return self._connection.create_job(
#     324     process_graph=cube.flat_graph(),
#     325     title=title,
#     326     description=description,
#     327     plan=plan,
#     328     budget=budget,
#     329     additional=job_options,
#     330 )
#
# File ~/.conda/envs/ml_env/lib/python3.11/site-packages/openeo/rest/connection.py:1561, in Connection.create_job(self, process_graph, title, description, plan, budget, additional)
#    1557 if additional:
#    1558     # TODO: get rid of this non-standard field? https://github.com/Open-EO/openeo-api/issues/276
#    1559     req["job_options"] = additional
# -> 1561 response = self.post("/jobs", json=req, expected_status=201)
#    1563 job_id = None
#    1564 if "openeo-identifier" in response.headers:
#
# File ~/.conda/envs/ml_env/lib/python3.11/site-packages/openeo/rest/connection.py:210, in RestApiConnection.post(self, path, json, **kwargs)
#     202 def post(self, path: str, json: Optional[dict] = None, **kwargs) -> Response:
#     203     """
#     204     Do POST request to REST API.
#     205
#    (...)
#     208     :return: response: Response
#     209     """
# --> 210     return self.request("post", path=path, json=json, allow_redirects=False, **kwargs)
#
# File ~/.conda/envs/ml_env/lib/python3.11/site-packages/openeo/rest/connection.py:747, in Connection.request(self, method, path, headers, auth, check_error, expected_status, **kwargs)
#     740     return super(Connection, self).request(
#     741         method=method, path=path, headers=headers, auth=auth,
#     742         check_error=check_error, expected_status=expected_status, **kwargs,
#     743     )
#     745 try:
#     746     # Initial request attempt
# --> 747     return _request()
#     748 except OpenEoApiError as api_exc:
#     749     if api_exc.http_status_code == 403 and api_exc.code == "TokenInvalid":
#     750         # Auth token expired: can we refresh?
#
# File ~/.conda/envs/ml_env/lib/python3.11/site-packages/openeo/rest/connection.py:740, in Connection.request.<locals>._request()
#     739 def _request():
# --> 740     return super(Connection, self).request(
#     741         method=method, path=path, headers=headers, auth=auth,
#     742         check_error=check_error, expected_status=expected_status, **kwargs,
#     743     )
#
# File ~/.conda/envs/ml_env/lib/python3.11/site-packages/openeo/rest/connection.py:139, in RestApiConnection.request(self, method, path, headers, auth, check_error, expected_status, **kwargs)
#     135     _log.debug("Request `{m} {u}` with headers {h}, auth {a}, kwargs {k}".format(
#     136         m=method.upper(), u=url, h=headers and headers.keys(), a=type(auth).__name__, k=list(kwargs.keys()))
#     137     )
#     138 with ContextTimer() as timer:
# --> 139     resp = self.session.request(
#     140         method=method,
#     141         url=url,
#     142         headers=self._merged_headers(headers),
#     143         auth=auth,
#     144         timeout=kwargs.pop("timeout", self.default_timeout),
#     145         **kwargs
#     146     )
#     147 if slow_response_threshold and timer.elapsed() > slow_response_threshold:
#     148     _log.warning("Slow response: `{m} {u}` took {e:.2f}s (>{t:.2f}s)".format(
#     149         m=method.upper(), u=str_truncate(url, width=64),
#     150         e=timer.elapsed(), t=slow_response_threshold
#     151     ))
#
# File ~/.conda/envs/ml_env/lib/python3.11/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/.conda/envs/ml_env/lib/python3.11/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/.conda/envs/ml_env/lib/python3.11/site-packages/requests/adapters.py:533, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     531     raise SSLError(e, request=request)
#     532 elif isinstance(e, ReadTimeoutError):
# --> 533     raise ReadTimeout(e, request=request)
#     534 elif isinstance(e, _InvalidHeader):
#     535     raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='openeo.dataspace.copernicus.eu', port=443): Read timed out. (read timeout=1200)

# %% [markdown]
# Download the timeseries CSV:

# %%
job.get_results().download_file("ndvi-results/timeseries-basic.csv")
pd.read_csv("ndvi-results/timeseries-basic.csv", index_col=0).head()
# Out:
#                           feature_index  avg(band_0)
# date
# 2020-06-11T00:00:00.000Z              3     0.020721
# 2020-06-14T00:00:00.000Z              1     0.105809
# 2020-06-14T00:00:00.000Z              0     0.121963
# 2020-06-11T00:00:00.000Z              1     0.024322
# 2020-06-14T00:00:00.000Z              3     0.096719

# %% [markdown]
# Create a quick plot helper to visualize the NDVI data:

# %%
def plot_timeseries(filename, figsize=(6, 3)):
    df = pd.read_csv(filename, index_col=0)
    df.index = pd.to_datetime(df.index)

    fig, ax = plt.subplots(figsize=figsize, dpi=90)
    df.groupby("feature_index")["avg(band_0)"].plot(marker="o", ax=ax)
    ax.set_title(filename.split("/")[-1])
    ax.set_ylabel("NDVI")
    ax.set_ylim(0, 1)
    ax.legend(title="parcel id", loc="lower left", ncol=2)

# %%
plot_timeseries("ndvi-results/timeseries-basic.csv")

# %% [markdown]
# ## Cloud Masking in NDVI
#
# The result above is a good start, but there is room for improvement to get smoother NDVI profiles.
#
# There are quite some outliers because we didn't filter out cloudy observations or pixels.
# We can use the "SCL" (scene classification) band from the "SENTINEL2_L2A" collection to focus on non-cloud pixels.
# Let's load an "SENTINEL2_L2A" data cube again, with the additional "SCL" band, and calculate the NDVI like before:

# %%
s2cube = connection.load_collection(
    "SENTINEL2_L2A",
    temporal_extent=["2020-06-01", "2020-10-01"],
    bands=["B04", "B08", "SCL"],
)
red = s2cube.band("B04")
nir = s2cube.band("B08")
ndvi = (nir - red) / (nir + red)

# %% [markdown]
# Now, from the "SCL" band we will build a mask to remove everything that is not class 4 ("vegetation") or 5 ("not vegetated").
# This mask data cube is 1 for pixels which we want to remove (clouds, cloud shadow, ...) and 0 for pixels we want to keep.

# %%
scl = s2cube.band("SCL")
mask = ~((scl == 4) | (scl == 5))

# %% [markdown]
# This mask is however a bit noisy (because of imperfect classification) and to be a bit conservative we also want to expand it a bit to exclude extra pixels at cloud edges.
# We can do this morphological operation by using a convolution with a gaussian kernel and applying a threshold to get a binary mask again.

# %%
# 2D gaussian kernel
g = scipy.signal.windows.gaussian(11, std=1.6)
kernel = np.outer(g, g)
kernel = kernel / kernel.sum()

# Morphological dilation of mask: convolution + threshold
mask = mask.apply_kernel(kernel)
mask = mask > 0.1

# %% [markdown]
# Now, we mask the NDVI data cube and do aggregation again:

# %%
ndvi_masked = ndvi.mask(mask)
timeseries_masked = ndvi_masked.aggregate_spatial(geometries=fields, reducer="mean")

# %%
job = timeseries_masked.execute_batch(out_format="CSV", title="Maked NDVI timeseries")
# Out:
# 0:00:00 Job 'j-231027418b984d498c00659dc928dfec': send 'start'
# 0:00:15 Job 'j-231027418b984d498c00659dc928dfec': created (progress N/A)
# 0:00:20 Job 'j-231027418b984d498c00659dc928dfec': created (progress N/A)
# 0:00:27 Job 'j-231027418b984d498c00659dc928dfec': created (progress N/A)
# 0:00:35 Job 'j-231027418b984d498c00659dc928dfec': created (progress N/A)
# 0:00:45 Job 'j-231027418b984d498c00659dc928dfec': created (progress N/A)
# 0:00:58 Job 'j-231027418b984d498c00659dc928dfec': created (progress N/A)
# 0:01:13 Job 'j-231027418b984d498c00659dc928dfec': running (progress N/A)
# 0:01:35 Job 'j-231027418b984d498c00659dc928dfec': running (progress N/A)
# 0:01:59 Job 'j-231027418b984d498c00659dc928dfec': running (progress N/A)
# 0:02:29 Job 'j-231027418b984d498c00659dc928dfec': running (progress N/A)
# 0:03:07 Job 'j-231027418b984d498c00659dc928dfec': running (progress N/A)
# 0:03:54 Job 'j-231027418b984d498c00659dc928dfec': running (progress N/A)
# 0:04:59 Job 'j-231027418b984d498c00659dc928dfec': finished (progress N/A)

# %%
job.get_results().download_file("ndvi-results/timeseries-masked.csv")
# Out:
# PosixPath('ndvi-results/timeseries-masked.csv')

# %%
plot_timeseries("ndvi-results/timeseries-masked.csv")

# %% [markdown]
# ## Timeseries Smoothing
#
# As final step in this demonstration we will add a openEO user-defined function (UDF) to the processing.
# A UDF allows to submit a snippet of, for example, Python code to be executed on the data at the backend side.
# In this case we'll define a UDF to:
#
# -  interpolate missing values (due to cloud filtering)
# -  apply a Savitzky-Golay filter for temporal smoothing of the timeseries (using `scipy.signal.savgol_filter`)
#
# We can load a UDF from an external file, but here we'll load it as an inline snippet:

# %%
udf = openeo.UDF(
    """
from scipy.signal import savgol_filter
from openeo.udf import XarrayDataCube

def apply_datacube(cube: XarrayDataCube, context: dict) -> XarrayDataCube:
    array = cube.get_array()
    filled = array.interpolate_na(dim='t')
    smoothed_array = savgol_filter(filled.values, 5, 2, axis=0)
    return DataCube(xarray.DataArray(smoothed_array, dims=array. dims,coords=array.coords))
"""
)

# %% [markdown]
# We apply this UDF along the time dimension of the `ndvi_masked` cube we created in the previous step:

# %%
ndvi_smoothed = ndvi_masked.apply_dimension(code=udf, dimension="t")

# %% [markdown]
# Now, aggregate this again per field and get the time series.

# %%
timeseries_smoothed = ndvi_smoothed.aggregate_spatial(geometries=fields, reducer="mean")

# %%
job = timeseries_smoothed.execute_batch(
    out_format="CSV", title="Smoothed NDVI timeseries"
)
# Out:
# 0:00:00 Job 'j-2310272f04d849b2882fe80cae71fff7': send 'start'
# 0:00:13 Job 'j-2310272f04d849b2882fe80cae71fff7': created (progress N/A)
# 0:00:18 Job 'j-2310272f04d849b2882fe80cae71fff7': created (progress N/A)
# 0:00:25 Job 'j-2310272f04d849b2882fe80cae71fff7': created (progress N/A)
# 0:00:33 Job 'j-2310272f04d849b2882fe80cae71fff7': created (progress N/A)
# 0:00:44 Job 'j-2310272f04d849b2882fe80cae71fff7': created (progress N/A)
# 0:00:57 Job 'j-2310272f04d849b2882fe80cae71fff7': running (progress N/A)
# 0:01:14 Job 'j-2310272f04d849b2882fe80cae71fff7': running (progress N/A)
# 0:01:35 Job 'j-2310272f04d849b2882fe80cae71fff7': running (progress N/A)
# 0:02:00 Job 'j-2310272f04d849b2882fe80cae71fff7': running (progress N/A)
# 0:02:33 Job 'j-2310272f04d849b2882fe80cae71fff7': running (progress N/A)
# 0:03:11 Job 'j-2310272f04d849b2882fe80cae71fff7': running (progress N/A)
# 0:03:58 Job 'j-2310272f04d849b2882fe80cae71fff7': running (progress N/A)
# 0:04:57 Job 'j-2310272f04d849b2882fe80cae71fff7': finished (progress N/A)

# %%
job.get_results().download_file("ndvi-results/timeseries-smoothed.csv")
# Out:
# PosixPath('ndvi-results/timeseries-smoothed.csv')

# %%
plot_timeseries("ndvi-results/timeseries-smoothed.csv")
